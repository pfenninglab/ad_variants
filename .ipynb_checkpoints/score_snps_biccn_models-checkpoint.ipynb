# %%
import pandas as pd
import numpy as np
from keras.models import Sequential, load_model
from scipy.stats import pearsonr, spearmanr
from scipy.special import logit
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib
rcParams.update({'figure.autolayout': True})
rcParams['svg.fonttype'] = 'none'
rcParams['font.size']=10

# %%
def shiftedColorMap(cmap, start=0, midpoint=0.5, stop=1.0, name='shiftedcmap'):
    '''
    Function to offset the "center" of a colormap. Useful for
    data with a negative min and positive max and you want the
    middle of the colormap's dynamic range to be at zero.

    Input
    -----
      cmap : The matplotlib colormap to be altered
      start : Offset from lowest point in the colormap's range.
          Defaults to 0.0 (no lower offset). Should be between
          0.0 and `midpoint`.
      midpoint : The new center of the colormap. Defaults to
          0.5 (no shift). Should be between 0.0 and 1.0. In
          general, this should be  1 - vmax / (vmax + abs(vmin))
          For example if your data range from -15.0 to +5.0 and
          you want the center of the colormap at 0.0, `midpoint`
          should be set to  1 - 5/(5 + 15)) or 0.75
      stop : Offset from highest point in the colormap's range.
          Defaults to 1.0 (no upper offset). Should be between
          `midpoint` and 1.0.
    '''
    cdict = {
        'red': [],
        'green': [],
        'blue': [],
        'alpha': []
    }

    # regular index to compute the colors
    reg_index = np.linspace(start, stop, 257)

    # shifted index to match the data
    shift_index = np.hstack([
        np.linspace(0.0, midpoint, 128, endpoint=False),
        np.linspace(midpoint, 1.0, 129, endpoint=True)
    ])

    for ri, si in zip(reg_index, shift_index):
        r, g, b, a = cmap(ri)

        cdict['red'].append((si, r, r))
        cdict['green'].append((si, g, g))
        cdict['blue'].append((si, b, b))
        cdict['alpha'].append((si, a, a))

    newcmap = matplotlib.colors.LinearSegmentedColormap(name, cdict)
    plt.register_cmap(cmap=newcmap)

    return newcmap

# %%
microglia_regression = load_model("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_gosselin_microglia/model_7.hdf5", compile = False)
microglia_classifier = load_model("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_gosselin_microglia/classification_model_4.hdf5", compile = False)

neuron_regression = load_model("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_fullard_neun/model_2.hdf5", compile = False)
neuron_classifier = load_model("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_fullard_neun/classification_model_4.hdf5", compile = False)

monocyte_regression = load_model("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_monocyte/model_8.hdf5", compile = False)
monocyte_classifier = load_model("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_monocyte/classification_model_4.hdf5", compile = False)

# %%
kunkleetal_bin1_ref_sequences = np.load("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_gosselin_microglia/kunkleetal_snps_overlapping_bin1_rough_region_reference.npy")
kunkleetal_bin1_alt_sequences = np.load("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_gosselin_microglia/kunkleetal_snps_overlapping_bin1_rough_region_alternate.npy")

jansenetal_bin1_ref_sequences = np.load("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_gosselin_microglia/jansenetal_snps_overlapping_bin1_rough_region_reference.npy")
jansenetal_bin1_alt_sequences = np.load("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_gosselin_microglia/jansenetal_snps_overlapping_bin1_rough_region_alternate.npy")

# %%
microglia_regression_kunkleetal_bin1_ref_sequences_scores = microglia_regression.predict(kunkleetal_bin1_ref_sequences) 
microglia_regression_kunkleetal_bin1_alt_sequences_scores = microglia_regression.predict(kunkleetal_bin1_alt_sequences)

microglia_classifier_kunkleetal_bin1_ref_sequences_scores = microglia_classifier.predict_proba(kunkleetal_bin1_ref_sequences)
microglia_classifier_kunkleetal_bin1_alt_sequences_scores = microglia_classifier.predict_proba(kunkleetal_bin1_alt_sequences)

# %%
neuron_regression_kunkleetal_bin1_ref_sequences_scores = neuron_regression.predict(kunkleetal_bin1_ref_sequences) 
neuron_regression_kunkleetal_bin1_alt_sequences_scores = neuron_regression.predict(kunkleetal_bin1_alt_sequences)

neuron_classifier_kunkleetal_bin1_ref_sequences_scores = neuron_classifier.predict_proba(kunkleetal_bin1_ref_sequences)
neuron_classifier_kunkleetal_bin1_alt_sequences_scores = neuron_classifier.predict_proba(kunkleetal_bin1_alt_sequences)

# %%
monocyte_regression_kunkleetal_bin1_ref_sequences_scores = monocyte_regression.predict(kunkleetal_bin1_ref_sequences) 
monocyte_regression_kunkleetal_bin1_alt_sequences_scores = monocyte_regression.predict(kunkleetal_bin1_alt_sequences)

monocyte_classifier_kunkleetal_bin1_ref_sequences_scores = monocyte_classifier.predict_proba(kunkleetal_bin1_ref_sequences)
monocyte_classifier_kunkleetal_bin1_alt_sequences_scores = monocyte_classifier.predict_proba(kunkleetal_bin1_alt_sequences)

# %%
jansenetal_bin1_snp_info = pd.read_csv("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_gosselin_microglia/jansenetal_snps_overlapping_bin1_rough_region_hg38_alleles_updated.txt", sep="\t", names=["CHR","START", "END","RSID","A1", "A2", "P", "Z"], header=None)
kunkleetal_bin1_snp_info = pd.read_csv("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_gosselin_microglia/kunkleetal_snps_overlapping_bin1_rough_region_hg38_alleles_updated.txt", sep="\t", names=["CHR","START", "END","RSID","A1", "A2", "P", "Z"], header=None)

# %%
fig,axs = plt.subplots(6,1, figsize=(20,10))
fig.subplots_adjust(hspace=0)

vmax = np.amax(microglia_regression_kunkleetal_bin1_ref_sequences_scores-microglia_regression_kunkleetal_bin1_alt_sequences_scores)
vmin = np.amin(microglia_regression_kunkleetal_bin1_ref_sequences_scores-microglia_regression_kunkleetal_bin1_alt_sequences_scores)
vmid = 1 - vmax / (vmax + abs(vmin))
new_cmap = shiftedColorMap(matplotlib.cm.coolwarm, midpoint=vmid, name='shrunk')


im = axs[0].scatter(kunkleetal_bin1_snp_info["END"], -np.log10(kunkleetal_bin1_snp_info["P"]), c=(microglia_regression_kunkleetal_bin1_ref_sequences_scores-microglia_regression_kunkleetal_bin1_alt_sequences_scores).flatten(), cmap=new_cmap, s=50)
axs[0].tick_params(axis='both', which='major', labelsize=12)
axs[0].set_xticks([])
axs[0].set_ylim([0,35])
cb = fig.colorbar(im,ax=axs[0])
cb.ax.tick_params(labelsize=12)

vmax = np.amax(np.log2(microglia_classifier_kunkleetal_bin1_ref_sequences_scores/microglia_classifier_kunkleetal_bin1_alt_sequences_scores))
vmin = np.amin(np.log2(microglia_classifier_kunkleetal_bin1_ref_sequences_scores/microglia_classifier_kunkleetal_bin1_alt_sequences_scores))
vmid = 1 - vmax / (vmax + abs(vmin))
new_cmap = shiftedColorMap(matplotlib.cm.coolwarm, midpoint=vmid, name='shrunk')

im = axs[1].scatter(kunkleetal_bin1_snp_info["END"], -np.log10(kunkleetal_bin1_snp_info["P"]), c=np.log2(microglia_classifier_kunkleetal_bin1_ref_sequences_scores/microglia_classifier_kunkleetal_bin1_alt_sequences_scores).flatten(), cmap=new_cmap, s=50)
axs[1].tick_params(axis='both', which='major', labelsize=12)
axs[1].set_xticks([])
axs[1].set_ylim([0,35])
cb = fig.colorbar(im,ax=axs[1])
cb.ax.tick_params(labelsize=12)


vmax = np.amax(neuron_regression_kunkleetal_bin1_ref_sequences_scores-neuron_regression_kunkleetal_bin1_alt_sequences_scores)
vmin = np.amin(neuron_regression_kunkleetal_bin1_ref_sequences_scores-neuron_regression_kunkleetal_bin1_alt_sequences_scores)
vmid = 1 - vmax / (vmax + abs(vmin))
new_cmap = shiftedColorMap(matplotlib.cm.coolwarm, midpoint=vmid, name='shrunk')


im = axs[2].scatter(kunkleetal_bin1_snp_info["END"], -np.log10(kunkleetal_bin1_snp_info["P"]), c=(neuron_regression_kunkleetal_bin1_ref_sequences_scores-neuron_regression_kunkleetal_bin1_alt_sequences_scores).flatten(), cmap=new_cmap, s=50)
axs[2].tick_params(axis='both', which='major', labelsize=12)
axs[2].set_xticks([])
axs[2].set_ylim([0,35])
cb = fig.colorbar(im,ax=axs[2])
cb.ax.tick_params(labelsize=12)

vmax = np.amax(np.log2(neuron_classifier_kunkleetal_bin1_ref_sequences_scores/neuron_classifier_kunkleetal_bin1_alt_sequences_scores))
vmin = np.amin(np.log2(neuron_classifier_kunkleetal_bin1_ref_sequences_scores/neuron_classifier_kunkleetal_bin1_alt_sequences_scores))
vmid = 1 - vmax / (vmax + abs(vmin))
new_cmap = shiftedColorMap(matplotlib.cm.coolwarm, midpoint=vmid, name='shrunk')



im = axs[3].scatter(kunkleetal_bin1_snp_info["END"], -np.log10(kunkleetal_bin1_snp_info["P"]), c=(np.log2(neuron_classifier_kunkleetal_bin1_ref_sequences_scores/neuron_classifier_kunkleetal_bin1_alt_sequences_scores).flatten()), cmap=new_cmap, s=50)
axs[3].tick_params(axis='both', which='major', labelsize=12)
axs[3].set_xticks([])
axs[3].set_ylim([0,35])
cb = fig.colorbar(im,ax=axs[3])
cb.ax.tick_params(labelsize=12)



vmax = np.amax(monocyte_regression_kunkleetal_bin1_ref_sequences_scores-monocyte_regression_kunkleetal_bin1_alt_sequences_scores)
vmin = np.amin(monocyte_regression_kunkleetal_bin1_ref_sequences_scores-monocyte_regression_kunkleetal_bin1_alt_sequences_scores)
vmid = 1 - vmax / (vmax + abs(vmin))
new_cmap = shiftedColorMap(matplotlib.cm.coolwarm, midpoint=vmid, name='shrunk')



im = axs[4].scatter(kunkleetal_bin1_snp_info["END"], -np.log10(kunkleetal_bin1_snp_info["P"]), c=(monocyte_regression_kunkleetal_bin1_ref_sequences_scores-monocyte_regression_kunkleetal_bin1_alt_sequences_scores).flatten(), cmap=new_cmap,s=50)
axs[4].tick_params(axis='both', which='major', labelsize=12)
axs[4].set_xticks([])
axs[4].set_ylim([0,35])
cb = fig.colorbar(im,ax=axs[4])
cb.ax.tick_params(labelsize=12)


vmax = np.amax(np.log2(monocyte_classifier_kunkleetal_bin1_ref_sequences_scores/monocyte_classifier_kunkleetal_bin1_alt_sequences_scores))
vmin = np.amin(np.log2(monocyte_classifier_kunkleetal_bin1_ref_sequences_scores/monocyte_classifier_kunkleetal_bin1_alt_sequences_scores))
vmid = 1 - vmax / (vmax + abs(vmin))
new_cmap = shiftedColorMap(matplotlib.cm.coolwarm, midpoint=vmid, name='shrunk')

im = axs[5].scatter(kunkleetal_bin1_snp_info["END"], -np.log10(kunkleetal_bin1_snp_info["P"]), c=(np.log2(monocyte_classifier_kunkleetal_bin1_ref_sequences_scores/monocyte_classifier_kunkleetal_bin1_alt_sequences_scores).flatten()), cmap=new_cmap,s=50)
axs[5].set_xlabel("Genome position",size=20)
axs[5].tick_params(axis='both', which='major', labelsize=12)
axs[5].ticklabel_format(style='plain', useOffset=False)
axs[5].set_ylim([0,35])
cb = fig.colorbar(im,ax=axs[5])
cb.ax.tick_params(labelsize=12)

plt.tight_layout()
plt.savefig("combined_bin1_scores.png")
plt.savefig("combined_bin1_scores.svg")
# Out:
# /home/eramamur/bin/miniconda3/envs/gpu_keras_theano/lib/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# plt.ylabel("Microglia regression predicted scores")
# plt.scatter(range(len(microglia_regression_kunkleetal_bin1_alt_sequences_scores)), sorted(np.absolute(microglia_regression_kunkleetal_bin1_ref_sequences_scores-microglia_regression_kunkleetal_bin1_alt_sequences_scores).flatten()))

# %%
plt.ylabel("Microglia classifier predicted scores")
plt.scatter(range(len(microglia_classifier_kunkleetal_bin1_alt_sequences_scores)), sorted(np.absolute(np.log2(microglia_classifier_kunkleetal_bin1_ref_sequences_scores/microglia_classifier_kunkleetal_bin1_alt_sequences_scores).flatten())))

# %%
plt.ylabel("Neuron regression predicted scores")
plt.scatter(range(len(neuron_regression_kunkleetal_bin1_alt_sequences_scores)), sorted(np.absolute(neuron_regression_kunkleetal_bin1_ref_sequences_scores-neuron_regression_kunkleetal_bin1_alt_sequences_scores).flatten()))

# %%
plt.ylabel("Neuron classifier predicted scores")
plt.ylim([0,4.5])
plt.scatter(range(len(neuron_classifier_kunkleetal_bin1_alt_sequences_scores)), sorted(np.absolute(np.log2(neuron_classifier_kunkleetal_bin1_ref_sequences_scores/neuron_classifier_kunkleetal_bin1_alt_sequences_scores).flatten())))

# %%
plt.ylabel("Monocyte regression predicted scores")
plt.scatter(range(len(monocyte_regression_kunkleetal_bin1_alt_sequences_scores)), sorted(np.absolute(monocyte_regression_kunkleetal_bin1_ref_sequences_scores-monocyte_regression_kunkleetal_bin1_alt_sequences_scores).flatten()))

# %%
plt.ylabel("Monocyte classifier predicted scores")
plt.scatter(range(len(monocyte_classifier_kunkleetal_bin1_alt_sequences_scores)), sorted(np.absolute(np.log2(monocyte_classifier_kunkleetal_bin1_ref_sequences_scores/monocyte_classifier_kunkleetal_bin1_alt_sequences_scores).flatten())))

# %%
snigdha_ad_ref_sequences = np.load("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ad_variants_processing/ref_1kb_sequences.npy")
snigdha_ad_alt_sequences = np.load("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ad_variants_processing/alt_1kb_sequences.npy")

# %%
microglia_regression_ad_ref_sequences_scores = microglia_regression.predict(snigdha_ad_ref_sequences) 
microglia_regression_ad_alt_sequences_scores = microglia_regression.predict(snigdha_ad_alt_sequences)

neuron_regression_ad_ref_sequences_scores = neuron_regression.predict(snigdha_ad_ref_sequences) 
neuron_regression_ad_alt_sequences_scores = neuron_regression.predict(snigdha_ad_alt_sequences)

monocyte_regression_ad_ref_sequences_scores = monocyte_regression.predict(snigdha_ad_ref_sequences) 
monocyte_regression_ad_alt_sequences_scores = monocyte_regression.predict(snigdha_ad_alt_sequences)

# %%
microglia_classifier_ad_ref_sequences_scores = microglia_classifier.predict(snigdha_ad_ref_sequences) 
microglia_classifier_ad_alt_sequences_scores = microglia_classifier.predict(snigdha_ad_alt_sequences)

neuron_classifier_ad_ref_sequences_scores = neuron_classifier.predict(snigdha_ad_ref_sequences) 
neuron_classifier_ad_alt_sequences_scores = neuron_classifier.predict(snigdha_ad_alt_sequences)

monocyte_classifier_ad_ref_sequences_scores = monocyte_classifier.predict(snigdha_ad_ref_sequences) 
monocyte_classifier_ad_alt_sequences_scores = monocyte_classifier.predict(snigdha_ad_alt_sequences)

# %%
plt.ylabel("Monocyte regression predicted scores")
plt.scatter(range(len(monocyte_regression_ad_ref_sequences_scores)), sorted(np.absolute(monocyte_regression_ad_ref_sequences_scores-monocyte_regression_ad_alt_sequences_scores).flatten()))
# Out:
# /home/eramamur/bin/miniconda3/envs/gpu_keras_theano/lib/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
plt.ylabel("Monocyte classifier predicted scores")
plt.scatter(range(len(monocyte_classifier_ad_ref_sequences_scores)), sorted(np.absolute(np.log2(monocyte_classifier_ad_ref_sequences_scores/monocyte_classifier_ad_alt_sequences_scores).flatten())))

# %%
plt.ylabel("Monocyte regression predicted scores")
plt.scatter(range(len(monocyte_regression_ad_alt_sequences_scores)), sorted(np.absolute(monocyte_regression_ad_ref_sequences_scores-monocyte_regression_ad_alt_sequences_scores).flatten()))

# %%
plt.ylabel("Monocyte classifier predicted scores")
plt.scatter(range(len(monocyte_classifier_ad_alt_sequences_scores)), sorted(np.absolute(np.log2(monocyte_classifier_ad_ref_sequences_scores/monocyte_classifier_ad_alt_sequences_scores).flatten())))

# %%
plt.ylabel("Monocyte regression predicted scores")
plt.scatter(range(len(monocyte_regression_ad_alt_sequences_scores)), sorted(np.absolute(monocyte_regression_ad_ref_sequences_scores-monocyte_regression_ad_alt_sequences_scores).flatten()))

# %%
plt.ylabel("Monocyte classifier predicted scores")
plt.scatter(range(len(monocyte_classifier_ad_alt_sequences_scores)), sorted(np.absolute(np.log2(monocyte_classifier_ad_ref_sequences_scores/monocyte_classifier_ad_alt_sequences_scores).flatten())))

# %%
snp_data = pd.read_csv("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ad_variants_processing/snigdha_snp_list_unique_haploreg_hg19_positions_1kb_and_500bp_sequences.txt",
                       sep='\t',
                       header=0)

# %%
snp_data["microglia_regression_ref_score"] = microglia_regression_ad_ref_sequences_scores
snp_data["microglia_regression_alt_score"] = microglia_regression_ad_alt_sequences_scores

snp_data["neuron_regression_ref_score"] = neuron_regression_ad_ref_sequences_scores
snp_data["neuron_regression_alt_score"] = neuron_regression_ad_alt_sequences_scores

snp_data["monocyte_regression_ref_score"] = monocyte_regression_ad_ref_sequences_scores
snp_data["monocyte_regression_alt_score"] = monocyte_regression_ad_alt_sequences_scores

snp_data["microglia_classifier_ref_score"] = microglia_classifier_ad_ref_sequences_scores
snp_data["microglia_classifier_alt_score"] = microglia_classifier_ad_alt_sequences_scores

snp_data["neuron_classifier_ref_score"] = neuron_classifier_ad_ref_sequences_scores
snp_data["neuron_classifier_alt_score"] = neuron_classifier_ad_alt_sequences_scores

snp_data["monocyte_classifier_ref_score"] = monocyte_classifier_ad_ref_sequences_scores
snp_data["monocyte_classifier_alt_score"] = monocyte_classifier_ad_alt_sequences_scores
# Out:
#   File "<ipython-input-36-e1ffc84a029d>", line 2
#     snp_data[]
#              ^
# SyntaxError: invalid syntax

# %%
neuron_regression_score = neuron_regression_ad_ref_sequences_scores-neuron_regression_ad_alt_sequences_scores
microglia_regression_score = microglia_regression_ad_ref_sequences_scores-microglia_regression_ad_alt_sequences_scores
monocyte_regression_score = monocyte_regression_ad_ref_sequences_scores-monocyte_regression_ad_alt_sequences_scores

neuron_regression_score = (neuron_regression_score)/np.std(neuron_regression_score)
microglia_regression_score = (microglia_regression_score)/np.std(microglia_regression_score)
monocyte_regression_score = (monocyte_regression_score)/np.std(monocyte_regression_score)


plt.hist(np.absolute(neuron_regression_score), bins=30, histtype='step', label='Neuron', density=True)
plt.hist(np.absolute(microglia_regression_score), bins=30, histtype='step', label='Microglia', density=True)
plt.hist(np.absolute(monocyte_regression_score), bins=30, histtype='step', label='Monocyte', density=True)
plt.legend()
plt.xlim(0,2)
# Out:
# (0, 2)

# %%
snp_data["neuron_regression_effect_score"] = neuron_regression_score
snp_data["microglia_regression_effect_score"] = microglia_regression_score
snp_data["monocyte_regression_effect_score"] = monocyte_regression_score

# %%
neuron_classifier_score = logit(neuron_classifier_ad_ref_sequences_scores)-logit(neuron_classifier_ad_alt_sequences_scores)
microglia_classifier_score = logit(microglia_classifier_ad_ref_sequences_scores)-logit(microglia_classifier_ad_alt_sequences_scores)
monocyte_classifier_score = logit(monocyte_classifier_ad_ref_sequences_scores)-logit(monocyte_classifier_ad_alt_sequences_scores)

neuron_classifier_score = (neuron_classifier_score)/np.std(neuron_classifier_score)
microglia_classifier_score = (microglia_classifier_score)/np.std(microglia_classifier_score)
monocyte_classifier_score = (monocyte_classifier_score)/np.std(monocyte_classifier_score)


plt.hist(np.absolute(neuron_classifier_score), bins=30, histtype='step', label='Neuron', density=True)
plt.hist(np.absolute(microglia_classifier_score), bins=30, histtype='step', label='Microglia', density=True)
plt.hist(np.absolute(monocyte_classifier_score), bins=30, histtype='step', label='Monocyte', density=True)
plt.legend()
plt.xlim(0,2)
# Out:
# (0, 2)
# /home/eramamur/bin/miniconda3/envs/gpu_keras_theano/lib/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
plt.scatter(neuron_regression_score, microglia_regression_score)
plt.xlabel("Neuron regression score")
plt.ylabel("Microglia regressions score")
print("Pearson", pearsonr(neuron_regression_score, microglia_regression_score))
print("Spearman", spearmanr(neuron_regression_score, microglia_regression_score))
# Out:
# Pearson (array([0.19912645], dtype=float32), array([2.8146751e-12], dtype=float32))
# Spearman SpearmanrResult(correlation=0.14970805632481016, pvalue=1.699104653635684e-07)

# %%
plt.scatter(monocyte_regression_score, microglia_regression_score)
plt.xlabel("Monocyte regression score")
plt.ylabel("Microglia regressions score")
print("Pearson", pearsonr(monocyte_regression_score, microglia_regression_score))
print("Spearman", spearmanr(monocyte_regression_score, microglia_regression_score))
# Out:
# Pearson (array([0.53228414], dtype=float32), array([0.], dtype=float32))
# Spearman SpearmanrResult(correlation=0.4824953155683022, pvalue=1.6522403733439072e-71)

# %%
plt.scatter(monocyte_regression_score, neuron_regression_score)
plt.xlabel("Monocyte regression score")
plt.ylabel("Neuron regressions score")
print("Pearson", pearsonr(monocyte_regression_score, neuron_regression_score))
print("Spearman", spearmanr(monocyte_regression_score, neuron_regression_score))
# Out:
# Pearson (array([0.26217082], dtype=float32), array([1.8785286e-20], dtype=float32))
# Spearman SpearmanrResult(correlation=0.15927577742236898, pvalue=2.5771154171228176e-08)

# %%
plt.scatter(neuron_classifier_score, microglia_classifier_score)
plt.xlabel("Neuron classifier score")
plt.ylabel("Microglia classifier score")
print("Pearson", pearsonr(neuron_classifier_score, microglia_classifier_score))
print("Spearman", spearmanr(neuron_classifier_score, microglia_classifier_score))
# Out:
# Pearson (array([0.4836036], dtype=float32), array([0.], dtype=float32))
# Spearman SpearmanrResult(correlation=0.5126711985832996, pvalue=5.328552786324714e-82)

# %%
plt.scatter(monocyte_classifier_score, microglia_classifier_score)
plt.xlabel("Monocyte classifier score")
plt.ylabel("Microglia classifier score")
print("Pearson", pearsonr(monocyte_classifier_score, microglia_classifier_score))
print("Spearman", spearmanr(monocyte_classifier_score, microglia_classifier_score))
# Out:
# Pearson (array([0.7437856], dtype=float32), array([0.], dtype=float32))
# Spearman SpearmanrResult(correlation=0.6999906042630244, pvalue=1.0987334875992829e-178)

# %%
plt.scatter(monocyte_classifier_score, neuron_classifier_score)
plt.xlabel("Monocyte classifier score")
plt.ylabel("Neuron classifier score")
print("Pearson", pearsonr(monocyte_classifier_score, neuron_classifier_score))
print("Spearman", spearmanr(monocyte_classifier_score, neuron_classifier_score))
# Out:
# Pearson (array([0.34012225], dtype=float32), array([4.022803e-34], dtype=float32))
# Spearman SpearmanrResult(correlation=0.3619523119816283, pvalue=9.898540810802786e-39)

# %%
plt.scatter(microglia_classifier_score, microglia_regression_score)
plt.xlabel("Microglia classifier score")
plt.ylabel("Microglia regression score")
print("Pearson", pearsonr(microglia_classifier_score, microglia_regression_score))
print("Spearman", spearmanr(microglia_classifier_score, microglia_regression_score))
# Out:
# Pearson (array([0.6662156], dtype=float32), array([0.], dtype=float32))
# Spearman SpearmanrResult(correlation=0.6713286392041721, pvalue=3.2903220217564e-159)

# %%
plt.scatter(monocyte_classifier_score, monocyte_regression_score)
plt.xlabel("Monocyte classifier score")
plt.ylabel("Monocyte regression score")
print("Pearson", pearsonr(monocyte_classifier_score, monocyte_regression_score))
print("Spearman", spearmanr(monocyte_classifier_score, monocyte_regression_score))
# Out:
# Pearson (array([0.5749748], dtype=float32), array([0.], dtype=float32))
# Spearman SpearmanrResult(correlation=0.4827210400599043, pvalue=1.391327472016985e-71)

# %%
plt.scatter(neuron_classifier_score, neuron_regression_score)
plt.xlabel("Neuron classifier score")
plt.ylabel("Neuron regression score")
print("Pearson", pearsonr(neuron_classifier_score, neuron_regression_score))
print("Spearman", spearmanr(neuron_classifier_score, neuron_regression_score))
# Out:
# Pearson (array([0.4407921], dtype=float32), array([0.], dtype=float32))
# Spearman SpearmanrResult(correlation=0.3785258107359318, pvalue=1.7721932368476454e-42)
