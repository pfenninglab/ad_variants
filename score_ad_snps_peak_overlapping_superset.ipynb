# %%
import pandas as pd
import numpy as np

from keras.models import Sequential, load_model
from scipy.stats import pearsonr, spearmanr

from scipy.special import logit


import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib
rcParams.update({'figure.autolayout': True})
rcParams['svg.fonttype'] = 'none'
rcParams['font.size']=10


import py2bit

# %%
snp_list_and_info = pd.read_csv("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ad_variants_processing/common_variants/snigdha_snp_list_unique_haploreg_hg19_positions.txt",
                                sep='\t'
                               )

# %%
leftWindow = 499
rightWindow = 500

# %%
snp_list_and_info.head()
# Out:
#      CHR  haploreg_hg19_pos     LD_RSID   REF ALT
# 0  chr10           11707563  rs34388456  GCCT   G
# 1  chr10           11707915  rs11257227     A   G
# 2  chr10           11714507  rs74347557     C   T
# 3  chr10           11714686  rs77892763     C   T
# 4  chr10           11717397  rs11257238     T   C

# %%
def oneHotEncodeSequence(sequence):
    oneHotDimension = (len(sequence), 4)
    dnaAlphabet = {"A":0, "G":1, "C":2, "T":3}    
    one_hot_encoded_sequence = np.zeros(oneHotDimension, dtype=np.int)
    for i, nucleotide in enumerate(sequence):
        if nucleotide.upper() in dnaAlphabet:
            index = dnaAlphabet[nucleotide.upper()]
            one_hot_encoded_sequence[i][index] = 1
    return one_hot_encoded_sequence


def getUpdatedPaddings(allele,left,right):
    alleleLength = len(allele)
    deductable = "right"
    for i in range(alleleLength-1):
        if deductable=="right":
            right-=1
            deductable="left"
        elif deductable=="left":
            left-=1
            deductable="right"

    return left,right

# %%
genome_object = py2bit.open("/home/eramamur/resources/genomes/hg19/hg19.2bit")

# %%
ref_sequences_list = []
alt_sequences_list = []

# %%
for i,row in snp_list_and_info.iterrows():
    referenceLeftWindow, referenceRightWindow = getUpdatedPaddings(row["REF"], leftWindow, rightWindow)
    alternateLeftWindow, alternateRightWindow = getUpdatedPaddings(row["ALT"], leftWindow, rightWindow)

    referenceLeftSequence = genome_object.sequence(row["CHR"],
                                                   row["haploreg_hg19_pos"]-referenceLeftWindow,
                                                   row["haploreg_hg19_pos"]
                                                  )
    referenceRightSequence = genome_object.sequence(row["CHR"],
                                                    row["haploreg_hg19_pos"]+len(row["REF"]),
                                                    row["haploreg_hg19_pos"]+len(row["REF"])+referenceRightWindow
                                                   )
    referenceSequence = referenceLeftSequence.lower() + row["REF"].upper() + referenceRightSequence.lower()

    alternateLeftSequence = genome_object.sequence(row["CHR"],
                                                   row["haploreg_hg19_pos"]-alternateLeftWindow,
                                                   row["haploreg_hg19_pos"]
                                                  )
    alternateRightSequence = genome_object.sequence(row["CHR"],
                                                    row["haploreg_hg19_pos"]+len(row["REF"]),
                                                    row["haploreg_hg19_pos"]+len(row["REF"])+alternateRightWindow
                                                   )
    alternateSequence = alternateLeftSequence.lower() + row["ALT"].upper() + alternateRightSequence.lower()
    ref_sequences_list.append(referenceSequence)
    alt_sequences_list.append(alternateSequence)

# %%
snp_list_and_info["REF_sequence_1kb"] = ref_sequences_list
snp_list_and_info["ALT_sequence_1kb"] = alt_sequences_list

# %%
indel_info = snp_list_and_info.loc[(snp_list_and_info["REF"].str.len()>1) | (snp_list_and_info["ALT"].str.len()>1)]

# %%
for i,row in indel_info.iterrows():
    print(row)
# Out:
# CHR                                 chr10
# haploreg_hg19_pos                11707563
# LD_RSID                        rs34388456
# REF                                  GCCT
# ALT                                     G
# REF_sequence_1kb     atgcccggGCCTctcctcct
# ALT_sequence_1kb     catgcccggGctcctcctcc
# Name: 0, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                59874475
# LD_RSID                       rs143391047
# REF                                  TTTG
# ALT                                     T
# REF_sequence_1kb     ccttttttTTTGtgttgttg
# ALT_sequence_1kb     accttttttTtgttgttgtt
# Name: 38, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                59874817
# LD_RSID                       rs143028487
# REF                                     T
# ALT                               TTTTCTC
# REF_sequence_1kb     gcctctcttTttctctgtct
# ALT_sequence_1kb     tctcttTTTTCTCttctctg
# Name: 39, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                59875585
# LD_RSID                        rs34901701
# REF                                  GCTT
# ALT                                     G
# REF_sequence_1kb     aggccacgGCTTtactcaaa
# ALT_sequence_1kb     caggccacgGtactcaaatg
# Name: 40, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                59918505
# LD_RSID                       rs138369826
# REF                                    CA
# ALT                                     C
# REF_sequence_1kb     gaattctccCAtgacataat
# ALT_sequence_1kb     gaattctccCtgacataatc
# Name: 80, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                59918613
# LD_RSID                        rs35408863
# REF                                  TCTC
# ALT                                     T
# REF_sequence_1kb     aagaagatTCTCtttattcc
# ALT_sequence_1kb     taagaagatTtttattccta
# Name: 81, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                59918612
# LD_RSID                       rs200623768
# REF                                   ATC
# ALT                                     A
# REF_sequence_1kb     taagaagaATCcctttattc
# ALT_sequence_1kb     ataagaagaAcctttattcc
# Name: 82, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                59932023
# LD_RSID                       rs200025446
# REF                                     A
# ALT                                   AAC
# REF_sequence_1kb     aaaaaaaaaAaaaaaaaaaa
# ALT_sequence_1kb     aaaaaaaaAACaaaaaaaaa
# Name: 99, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                59932024
# LD_RSID                       rs199902507
# REF                                     A
# ALT                                    AC
# REF_sequence_1kb     aaaaaaaaaAaaaaaaaaac
# ALT_sequence_1kb     aaaaaaaaaACaaaaaaaaa
# Name: 100, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                59958687
# LD_RSID                        rs35044136
# REF                                    GA
# ALT                                     G
# REF_sequence_1kb     taaaaaatgGAaaaaaaaat
# ALT_sequence_1kb     taaaaaatgGaaaaaaaatc
# Name: 126, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                59993346
# LD_RSID                       rs201931677
# REF                                     T
# ALT                                    TA
# REF_sequence_1kb     cttttttttTaaaaaaagaa
# ALT_sequence_1kb     cttttttttTAaaaaaaaga
# Name: 159, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                60011510
# LD_RSID                       rs144752623
# REF                                 GGGTA
# ALT                                     G
# REF_sequence_1kb     aacgttgGGGTAgtaggcag
# ALT_sequence_1kb     tcaacgttgGgtaggcagag
# Name: 171, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                85670385
# LD_RSID                        rs68172244
# REF                                   CAA
# ALT                                     C
# REF_sequence_1kb     caaagctcCAAggctgggca
# ALT_sequence_1kb     tcaaagctcCggctgggcac
# Name: 205, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                85671252
# LD_RSID                        rs67911082
# REF                                     A
# ALT                                 AATCT
# REF_sequence_1kb     atccaaagaAtactgaagta
# ALT_sequence_1kb     ccaaagaAATCTtactgaag
# Name: 207, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                85671252
# LD_RSID                        rs67911082
# REF                                     A
# ALT                                   ATC
# REF_sequence_1kb     atccaaagaAtactgaagta
# ALT_sequence_1kb     tccaaagaATCtactgaagt
# Name: 208, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                85733813
# LD_RSID                       rs200189296
# REF                                     A
# ALT                                   AAC
# REF_sequence_1kb     attagaaaaAcgttctttta
# ALT_sequence_1kb     ttagaaaaAACcgttctttt
# Name: 216, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                85742217
# LD_RSID                        rs71040206
# REF                                    CA
# ALT                                     C
# REF_sequence_1kb     gatatagacCAaatatatag
# ALT_sequence_1kb     gatatagacCaatatatagt
# Name: 220, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                85748296
# LD_RSID                       rs200041034
# REF                                    AG
# ALT                                     A
# REF_sequence_1kb     aaaaaaaaaAGaaatttttt
# ALT_sequence_1kb     aaaaaaaaaAaaattttttt
# Name: 223, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                85774419
# LD_RSID                        rs10546552
# REF                                   GTA
# ALT                                     G
# REF_sequence_1kb     acaaaaggGTAatagatgcc
# ALT_sequence_1kb     cacaaaaggGatagatgccc
# Name: 232, dtype: object
# CHR                                 chr11
# haploreg_hg19_pos                85839407
# LD_RSID                       rs144587195
# REF                                     T
# ALT                      TTAGTTGGGACATTCC
# REF_sequence_1kb     acagatactTagtttttctt
# ALT_sequence_1kb     ctTTAGTTGGGACATTCCag
# Name: 257, dtype: object
# CHR                                 chr14
# haploreg_hg19_pos                53312775
# LD_RSID                       rs147655286
# REF                                     G
# ALT                               GCACGAC
# REF_sequence_1kb     acaggtgtgGacgaccatac
# ALT_sequence_1kb     ggtgtgGCACGACacgacca
# Name: 298, dtype: object
# CHR                                 chr14
# haploreg_hg19_pos                53329969
# LD_RSID                        rs11443039
# REF                                     A
# ALT                                    AC
# REF_sequence_1kb     tcattaaaaAtctgaacatt
# ALT_sequence_1kb     tcattaaaaACtctgaacat
# Name: 318, dtype: object
# CHR                                 chr14
# haploreg_hg19_pos                53349505
# LD_RSID                       rs202222431
# REF                                     G
# ALT                                GAAGCA
# REF_sequence_1kb     tagtctaggGagcaaagtta
# ALT_sequence_1kb     gtctaggGAAGCAagcaaag
# Name: 338, dtype: object
# CHR                                 chr14
# haploreg_hg19_pos                53359165
# LD_RSID                       rs200499737
# REF                                     C
# ALT                              CTGTTTTT
# REF_sequence_1kb     gcctggtgcCgttttttgtt
# ALT_sequence_1kb     tggtgcCTGTTTTTgttttt
# Name: 347, dtype: object
# CHR                                 chr14
# haploreg_hg19_pos                53365451
# LD_RSID                        rs34012538
# REF                                     A
# ALT                                   ACT
# REF_sequence_1kb     gtggtggtaAtctctctcca
# ALT_sequence_1kb     tggtggtaACTtctctctcc
# Name: 353, dtype: object
# CHR                                 chr14
# haploreg_hg19_pos                53366013
# LD_RSID                       rs148837982
# REF                                     T
# ALT                                    TA
# REF_sequence_1kb     tatttatttTttttgagacg
# ALT_sequence_1kb     tatttatttTAttttgagac
# Name: 354, dtype: object
# CHR                                 chr14
# haploreg_hg19_pos                53367213
# LD_RSID                        rs75192018
# REF                                     C
# ALT                                    CA
# REF_sequence_1kb     actcctttcCaaatcacgta
# ALT_sequence_1kb     actcctttcCAaaatcacgt
# Name: 357, dtype: object
# CHR                                 chr14
# haploreg_hg19_pos                53434187
# LD_RSID                        rs35169358
# REF                                    TG
# ALT                                     T
# REF_sequence_1kb     gggattactTGtgtgagcca
# ALT_sequence_1kb     gggattactTtgtgagccac
# Name: 370, dtype: object
# CHR                                 chr15
# haploreg_hg19_pos                59019404
# LD_RSID                        rs34158903
# REF                                    TC
# ALT                                     T
# REF_sequence_1kb     tttttttttTCcaaaaacag
# ALT_sequence_1kb     tttttttttTcaaaaacagc
# Name: 389, dtype: object
# CHR                                 chr15
# haploreg_hg19_pos                59022200
# LD_RSID                       rs199804400
# REF                                   AAC
# ALT                                     A
# REF_sequence_1kb     acaaacaaAACaaaaaaaaa
# ALT_sequence_1kb     aacaaacaaAaaaaaaaaaa
# Name: 390, dtype: object
# CHR                                 chr15
# haploreg_hg19_pos                59022201
# LD_RSID                        rs67959704
# REF                                    AC
# ALT                                     A
# REF_sequence_1kb     acaaacaaaACaaaaaaaaa
# ALT_sequence_1kb     acaaacaaaAaaaaaaaaaa
# Name: 391, dtype: object
# CHR                                 chr15
# haploreg_hg19_pos                59082786
# LD_RSID                       rs200199753
# REF                                    GT
# ALT                                     G
# REF_sequence_1kb     agaccttagGTgggggtaag
# ALT_sequence_1kb     agaccttagGgggggtaaga
# Name: 416, dtype: object
# CHR                                 chr17
# haploreg_hg19_pos                47444562
# LD_RSID                        rs67726002
# REF                                   GTT
# ALT                                     G
# REF_sequence_1kb     gtcaggagGTTgagaccacc
# ALT_sequence_1kb     ggtcaggagGgagaccaccc
# Name: 503, dtype: object
# CHR                                 chr17
# haploreg_hg19_pos                 5111998
# LD_RSID                       rs200609797
# REF                                     T
# ALT                                    TC
# REF_sequence_1kb     actcagtctTaaaaaaaaaa
# ALT_sequence_1kb     actcagtctTCaaaaaaaaa
# Name: 512, dtype: object
# CHR                                 chr17
# haploreg_hg19_pos                 5198839
# LD_RSID                       rs148132952
# REF                                TAAATA
# ALT                                     T
# REF_sequence_1kb     tgtctctTAAATAttagcca
# ALT_sequence_1kb     tgtgtctctTttagccaaat
# Name: 536, dtype: object
# CHR                                 chr17
# haploreg_hg19_pos                 5254433
# LD_RSID                       rs146414631
# REF                                   GAC
# ALT                                     G
# REF_sequence_1kb     aagattggGACcctgctcta
# ALT_sequence_1kb     aaagattggGcctgctctaa
# Name: 558, dtype: object
# CHR                                 chr19
# haploreg_hg19_pos                45367277
# LD_RSID                       rs201138989
# REF                                     C
# ALT                                    CG
# REF_sequence_1kb     tccccccccCcaaaaaaaaa
# ALT_sequence_1kb     tccccccccCGcaaaaaaaa
# Name: 605, dtype: object
# CHR                                 chr19
# haploreg_hg19_pos                51734857
# LD_RSID                       rs199635234
# REF                                    TG
# ALT                                     T
# REF_sequence_1kb     ttggctgatTGttttttttt
# ALT_sequence_1kb     ttggctgatTtttttttttt
# Name: 621, dtype: object
# CHR                                 chr19
# haploreg_hg19_pos                51735023
# LD_RSID                        rs34912427
# REF                                     T
# ALT                                    TA
# REF_sequence_1kb     tttattattTtttttttgag
# ALT_sequence_1kb     tttattattTAtttttttga
# Name: 622, dtype: object
# CHR                                 chr20
# haploreg_hg19_pos                54979828
# LD_RSID                       rs200972527
# REF                                     A
# ALT                              AGTAGCTG
# REF_sequence_1kb     gcctcccaaAtagctgggac
# ALT_sequence_1kb     tcccaaAGTAGCTGtagctg
# Name: 627, dtype: object
# CHR                                  chr4
# haploreg_hg19_pos                11041549
# LD_RSID                        rs55706526
# REF                                   AAT
# ALT                                     A
# REF_sequence_1kb     aacaaccaAATtcaatcagc
# ALT_sequence_1kb     aaacaaccaAtcaatcagca
# Name: 679, dtype: object
# CHR                                  chr4
# haploreg_hg19_pos                11671182
# LD_RSID                       rs112079809
# REF                                    AC
# ALT                                     A
# REF_sequence_1kb     gacaggataACccttttttt
# ALT_sequence_1kb     gacaggataAcctttttttt
# Name: 686, dtype: object
# CHR                                  chr4
# haploreg_hg19_pos                11671605
# LD_RSID                       rs148731733
# REF                                     A
# ALT                                 ATTGT
# REF_sequence_1kb     gaattggtaAtgtgtgtgtg
# ALT_sequence_1kb     attggtaATTGTtgtgtgtg
# Name: 688, dtype: object
# CHR                                  chr4
# haploreg_hg19_pos                11757144
# LD_RSID                        rs34010171
# REF                                 CATAT
# ALT                                     C
# REF_sequence_1kb     caaggacCATATtatatatg
# ALT_sequence_1kb     cacaaggacCtatatatggt
# Name: 767, dtype: object
# CHR                                  chr4
# haploreg_hg19_pos                11757450
# LD_RSID                        rs35388525
# REF                                    GC
# ALT                                     G
# REF_sequence_1kb     tttgagttgGCatgtaataa
# ALT_sequence_1kb     tttgagttgGatgtaataaa
# Name: 768, dtype: object
# CHR                                  chr4
# haploreg_hg19_pos                11757964
# LD_RSID                        rs11321903
# REF                                    CT
# ALT                                     C
# REF_sequence_1kb     gagttgtgcCTctttaagaa
# ALT_sequence_1kb     gagttgtgcCctttaagaat
# Name: 769, dtype: object
# CHR                                  chr4
# haploreg_hg19_pos                11758946
# LD_RSID                        rs33957774
# REF                                CCTCTT
# ALT                                     C
# REF_sequence_1kb     aagactcCCTCTTtatttcc
# ALT_sequence_1kb     ctaagactcCtatttcctaa
# Name: 774, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32566609
# LD_RSID                         rs9279768
# REF                                   GTA
# ALT                                     G
# REF_sequence_1kb     tacaatagGTAagttaacaa
# ALT_sequence_1kb     atacaatagGagttaacaag
# Name: 808, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32567431
# LD_RSID                       rs142660963
# REF                                  TAAC
# ALT                                     T
# REF_sequence_1kb     aaaacaatTAACacaacaac
# ALT_sequence_1kb     aaaaacaatTacaacaacaa
# Name: 815, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32567719
# LD_RSID                        rs70993896
# REF                                    TA
# ALT                                     T
# REF_sequence_1kb     tgaaactgtTAaaatactag
# ALT_sequence_1kb     tgaaactgtTaaatactaga
# Name: 819, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32569823
# LD_RSID                       rs146374182
# REF                                   AAT
# ALT                                     A
# REF_sequence_1kb     caaaaaaaAATacaataatt
# ALT_sequence_1kb     ccaaaaaaaAacaataattt
# Name: 832, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32569823
# LD_RSID                       rs146374182
# REF                                   AAT
# ALT                                    AA
# REF_sequence_1kb     caaaaaaaAATacaataatt
# ALT_sequence_1kb     ccaaaaaaaAAacaataatt
# Name: 833, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32570524
# LD_RSID                        rs72318718
# REF                                  AAAT
# ALT                                     A
# REF_sequence_1kb     agtgtgaaAAATatgagaaa
# ALT_sequence_1kb     tagtgtgaaAatgagaaaat
# Name: 851, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32572571
# LD_RSID                        rs67141839
# REF                                GGACAT
# ALT                                     G
# REF_sequence_1kb     aaattagGGACATacatagg
# ALT_sequence_1kb     ataaattagGacataggtgg
# Name: 895, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32572895
# LD_RSID                       rs150986494
# REF                                     T
# ALT                                 TCAGA
# REF_sequence_1kb     ttctaccttTactttgtttc
# ALT_sequence_1kb     ctaccttTCAGAactttgtt
# Name: 902, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32572895
# LD_RSID                       rs150986494
# REF                                     T
# ALT                                TCCAGA
# REF_sequence_1kb     ttctaccttTactttgtttc
# ALT_sequence_1kb     ctaccttTCCAGAactttgt
# Name: 903, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32573985
# LD_RSID                         rs9281928
# REF                                     A
# ALT                                    AG
# REF_sequence_1kb     gaatcataaAaaaatgttca
# ALT_sequence_1kb     gaatcataaAGaaaatgttc
# Name: 931, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32576282
# LD_RSID                         rs9281938
# REF                                     T
# ALT                                    TA
# REF_sequence_1kb     tgtaatgctTgatctcatca
# ALT_sequence_1kb     tgtaatgctTAgatctcatc
# Name: 983, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32576391
# LD_RSID                        rs71705525
# REF                                  AACG
# ALT                                     A
# REF_sequence_1kb     taagaagaAACGgcagggac
# ALT_sequence_1kb     ataagaagaAgcagggacaa
# Name: 986, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32579901
# LD_RSID                       rs202092830
# REF                                     G
# ALT                                   GCA
# REF_sequence_1kb     caccttgggGacgttctcag
# ALT_sequence_1kb     accttgggGCAacgttctca
# Name: 1042, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32579904
# LD_RSID                         rs9281945
# REF                                     C
# ALT                                   CAT
# REF_sequence_1kb     cttgggcacCttctcaggat
# ALT_sequence_1kb     ttgggcacCATttctcagga
# Name: 1043, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32580344
# LD_RSID                         rs9281946
# REF                                     C
# ALT                                    CT
# REF_sequence_1kb     ctgcagaccCactctatggt
# ALT_sequence_1kb     ctgcagaccCTactctatgg
# Name: 1051, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                32581740
# LD_RSID                       rs111710395
# REF                                    AT
# ALT                                     A
# REF_sequence_1kb     gaaaaaaaaATtcagtattc
# ALT_sequence_1kb     gaaaaaaaaAtcagtattca
# Name: 1061, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                47437697
# LD_RSID                        rs34245545
# REF                                    AC
# ALT                                     A
# REF_sequence_1kb     tgataaaaaACccccaaaaa
# ALT_sequence_1kb     tgataaaaaAccccaaaaaa
# Name: 1084, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                47442154
# LD_RSID                        rs60924431
# REF                                    TA
# ALT                                     T
# REF_sequence_1kb     gagtgctttTAaaataatat
# ALT_sequence_1kb     gagtgctttTaaataatata
# Name: 1087, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                47464969
# LD_RSID                       rs142277866
# REF                        CTTTTCCTTTTCTT
# ALT                                     C
# REF_sequence_1kb     tccCTTTTCCTTTTCTTttt
# ALT_sequence_1kb     ttcctttccCtttcctttcc
# Name: 1100, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                47487097
# LD_RSID                        rs67769713
# REF                               TGTGATG
# ALT                                     T
# REF_sequence_1kb     ctgcatTGTGATGtttgggt
# ALT_sequence_1kb     aggctgcatTtttgggtttc
# Name: 1114, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                47550529
# LD_RSID                        rs67325630
# REF                                   TTG
# ALT                                     T
# REF_sequence_1kb     ttttgtttTTGttttttttt
# ALT_sequence_1kb     tttttgtttTtttttttttt
# Name: 1137, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                47587049
# LD_RSID                       rs143419962
# REF                                 AACAT
# ALT                                     A
# REF_sequence_1kb     catgagaAACATcaatgttt
# ALT_sequence_1kb     tccatgagaAcaatgtttga
# Name: 1160, dtype: object
# CHR                                  chr6
# haploreg_hg19_pos                47587294
# LD_RSID                        rs34945135
# REF                                  ACTT
# ALT                                     A
# REF_sequence_1kb     aataatgaACTTttttcctc
# ALT_sequence_1kb     gaataatgaAttttcctctg
# Name: 1161, dtype: object
# CHR                                  chr8
# haploreg_hg19_pos                27205046
# LD_RSID                        rs57735330
# REF                                    AG
# ALT                                     A
# REF_sequence_1kb     ttcttctgaAGcctctctat
# ALT_sequence_1kb     ttcttctgaAcctctctatt
# Name: 1185, dtype: object
